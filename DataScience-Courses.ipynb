# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

# %matplotlib inline

# %%
data = pd.read_csv('./datas/Publicité.csv', index_col=0, delimiter=";")
data.head()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %% [markdown]
# ## Regression Linéaire

# %%
plt.figure(figsize=(16,8))
plt.scatter(data['TV'], data['sales'], c='black')
plt.xlabel('Argent dépensé dans la pub TV (€)')
plt.ylabel('Ventes (k€)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-e6ac7206ad93> in <module>
#       1 plt.figure(figsize=(16,8))
#       2 plt.scatter(data['TV'], data['sales'], c='black')
# ----> 3 plt.xlabel('Argent dépensé dans la pub TV (€)')
#       4 plt.ylabel('Ventes (k€)')
#       5 plt.show()
#
# TypeError: 'str' object is not callable

# %%
X = data['TV'].values.reshape(-1,1)
y = data['sales'].values.reshape(-1,1)


reg = LinearRegression()
reg.fit(X,y)

print(f"Modèle lineaire \n Y= {reg.intercept_[0]} + {reg.coef_[0][0]} * TV")
# Out:
# Modèle lineaire
#  Y= 7.032593549127693 + 0.047536640433019764 * TV

# %%
predictions = reg.predict(X)

plt.figure(figsize=(16,8))
plt.scatter(X,y, c='black')
plt.plot(X, predictions)

plt.show()
